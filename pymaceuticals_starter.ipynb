# %% [markdown]
# ## Observations and Insights

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import scipy.stats as st

# Study data files
mouse_metadata_path = "Mouse_metadata.csv"
study_results_path = "Study_results.csv"

# Read the mouse data and the study results
mouse_metadata = pd.read_csv(mouse_metadata_path)
study_results = pd.read_csv(study_results_path)

# Combine the data into a single dataset, Merge two dataframes using an inner join
merge_df = pd.merge(mouse_metadata, study_results, on="Mouse ID")
merge_df
# Out:
#      Mouse ID Drug Regimen   Sex  Age_months  Weight (g)  Timepoint  \
# 0        k403     Ramicane  Male          21          16          0
# 1        k403     Ramicane  Male          21          16          5
# 2        k403     Ramicane  Male          21          16         10
# 3        k403     Ramicane  Male          21          16         15
# 4        k403     Ramicane  Male          21          16         20
# ...       ...          ...   ...         ...         ...        ...
# 1888     z969     Naftisol  Male           9          30         25
# 1889     z969     Naftisol  Male           9          30         30
# 1890     z969     Naftisol  Male           9          30         35
# 1891     z969     Naftisol  Male           9          30         40
# 1892     z969     Naftisol  Male           9          30         45
#
#       Tumor Volume (mm3)  Metastatic Sites
# 0              45.000000                 0
# 1              38.825898                 0
# ...

# %%
# Checking the number of mice in the DataFrame, Calculating the number of unique mice in the DataFrame
mice_number_count_df = len(merge_df["Mouse ID"].unique())
print(mice_number_count_df)
# Out:
# 249

# %%
# Getting the duplicate mice by ID number that shows up for Mouse ID and Timepoint. 
merge_df.drop_duplicates(subset = ["Mouse ID","Timepoint"],inplace = True)
print(merge_df)
# Out:
# Mouse ID Drug Regimen   Sex  Age_months  Weight (g)  Timepoint  \
# 0        k403     Ramicane  Male          21          16          0
# 1        k403     Ramicane  Male          21          16          5
# 2        k403     Ramicane  Male          21          16         10
# 3        k403     Ramicane  Male          21          16         15
# 4        k403     Ramicane  Male          21          16         20
# ...       ...          ...   ...         ...         ...        ...
# 1888     z969     Naftisol  Male           9          30         25
# 1889     z969     Naftisol  Male           9          30         30
# 1890     z969     Naftisol  Male           9          30         35
# 1891     z969     Naftisol  Male           9          30         40
# 1892     z969     Naftisol  Male           9          30         45
#
#       Tumor Volume (mm3)  Metastatic Sites
# 0              45.000000                 0
# 1              38.825898                 0
# ...

# %%
# Optional: Get all the data for the duplicate mouse ID.

# %%
# Getting the duplicate mice by ID number that shows up for Mouse ID and Timepoint. 
merge_df.drop_duplicates(subset = ["Mouse ID","Timepoint"],inplace = True)
print(merge_df)
# Out:
# Mouse ID Drug Regimen   Sex  Age_months  Weight (g)  Timepoint  \
# 0        k403     Ramicane  Male          21          16          0
# 1        k403     Ramicane  Male          21          16          5
# 2        k403     Ramicane  Male          21          16         10
# 3        k403     Ramicane  Male          21          16         15
# 4        k403     Ramicane  Male          21          16         20
# ...       ...          ...   ...         ...         ...        ...
# 1888     z969     Naftisol  Male           9          30         25
# 1889     z969     Naftisol  Male           9          30         30
# 1890     z969     Naftisol  Male           9          30         35
# 1891     z969     Naftisol  Male           9          30         40
# 1892     z969     Naftisol  Male           9          30         45
#
#       Tumor Volume (mm3)  Metastatic Sites
# 0              45.000000                 0
# 1              38.825898                 0
# ...

# %%
# length of clean data frame
clean_mice_number_count_df = merge_df
clean_mice_number_count_df
length_df = len(clean_mice_number_count_df)
length_df
# Out:
# 1888

# %%
## Summary Statistics

# %%
# Generate a summary statistics table of mean, median, variance, standard deviation, and SEM of the tumor volume for each regimen

# This method is the most straighforward, creating multiple series and putting them all together at the end.

# %%
# Generate a summary statistics table of mean, median, variance, standard deviation, and SEM of the tumor volume for each regimen

merge_df
print(merge_df.head(2))
# Summary statistics Data per Regimen 
Regimen_Merged_group_df = merge_df.groupby(['Drug Regimen'])
Regimen_Merged_group_df.describe()
# Out:
# Mouse ID Drug Regimen   Sex  Age_months  Weight (g)  Timepoint  \
# 0     k403     Ramicane  Male          21          16          0
# 1     k403     Ramicane  Male          21          16          5
#
#    Tumor Volume (mm3)  Metastatic Sites
# 0           45.000000                 0
# 1           38.825898                 0
#              Age_months                                                     \
#                   count       mean       std  min    25%   50%   75%   max
# Drug Regimen
# Capomulin         230.0  13.456522  7.721423  1.0   7.00  16.5  20.0  24.0
# Ceftamin          178.0  13.247191  8.071406  2.0   6.00  12.0  20.0  24.0
# Infubinol         178.0  16.230337  7.510278  1.0   8.00  20.0  23.0  24.0
# Ketapril          188.0  15.659574  6.019670  1.0  11.75  18.0  19.0  24.0
# Naftisol          186.0  12.000000  6.715855  2.0   8.00   9.0  19.0  23.0
# Placebo           181.0  10.734807  6.354907  1.0   5.00  10.0  17.0  21.0
# ...

# %% [markdown]
# ## Bar Plots

# %%
# Generate a bar plot showing the number of mice per time point for each treatment throughout the course of the study using pandas.

# %%
# Generate a bar plot showing the number of mice per time point for each treatment throughout the course of the study using pyplot.

# Below plot is for the Drug Treatment Regimen: Ramicane
# 9 other plots is still required for other Regimen 

import matplotlib.pyplot as plt
import numpy as np

#study_results
df = merge_df[["Drug Regimen","Mouse ID","Timepoint"]]
df.head(1)
df.drop_duplicates(subset = ["Mouse ID","Timepoint"],inplace = True)
print(df.head(5))

# number of mice per time(0) point for treatment "Ramicane"
mice_per_0_treatment_Ramicane = df.loc[(df["Drug Regimen"] == "Ramicane") & (df["Timepoint"] == 0), :]
print(len(mice_per_0_treatment_Ramicane))

# number of mice per time point(5) for treatment "Ramicane"
mice_per_5_treatment_Ramicane = df.loc[(df["Drug Regimen"] == "Ramicane") & (df["Timepoint"] == 5), :]
print(len(mice_per_5_treatment_Ramicane))

# number of mice per time point(10) for treatment "Ramicane"
mice_per_10_treatment_Ramicane = df.loc[(df["Drug Regimen"] == "Ramicane") & (df["Timepoint"] == 10), :]
print(len(mice_per_10_treatment_Ramicane))

# number of mice per time point(15) for treatment "Ramicane"
mice_per_15_treatment_Ramicane = df.loc[(df["Drug Regimen"] == "Ramicane") & (df["Timepoint"] == 15), :]
print(len(mice_per_15_treatment_Ramicane))

# number of mice per time point(20) for treatment "Ramicane"
mice_per_20_treatment_Ramicane = df.loc[(df["Drug Regimen"] == "Ramicane") & (df["Timepoint"] == 20), :]
print(len(mice_per_20_treatment_Ramicane))

# number of mice per time point(25) for treatment "Ramicane"
mice_per_25_treatment_Ramicane = df.loc[(df["Drug Regimen"] == "Ramicane") & (df["Timepoint"] == 25), :]
print(len(mice_per_25_treatment_Ramicane))

# number of mice per time point(30) for treatment "Ramicane"
mice_per_30_treatment_Ramicane = df.loc[(df["Drug Regimen"] == "Ramicane") & (df["Timepoint"] == 30), :]
print(len(mice_per_30_treatment_Ramicane))

# number of mice per time point(35) for treatment "Ramicane"
mice_per_35_treatment_Ramicane = df.loc[(df["Drug Regimen"] == "Ramicane") & (df["Timepoint"] == 35), :]
print(len(mice_per_35_treatment_Ramicane))

# number of mice per time point(40) for treatment "Ramicane"
mice_per_40_treatment_Ramicane = df.loc[(df["Drug Regimen"] == "Ramicane") & (df["Timepoint"] == 40), :]
print(len(mice_per_40_treatment_Ramicane))

# number of mice per time point(45) for treatment "Ramicane"
mice_per_45_treatment_Ramicane = df.loc[(df["Drug Regimen"] == "Ramicane") & (df["Timepoint"] == 45), :]
print(len(mice_per_45_treatment_Ramicane))

number_of_mice_per_time_point = [ 25, 25, 24, 24, 23, 23, 23, 21, 20, 20]
x_axis = [ 0, 5, 10, 15, 20, 25, 30, 35, 40, 45]

# Create a bar chart based upon the above data
plt.bar(x_axis, number_of_mice_per_time_point, color="b", align="center")

plt.title("Drug Treatment Regimen: Ramicane")
plt.xlabel("Timepoint")
plt.ylabel("Number of mice")
# Out:
# Drug Regimen Mouse ID  Timepoint
# 0     Ramicane     k403          0
# 1     Ramicane     k403          5
# 2     Ramicane     k403         10
# 3     Ramicane     k403         15
# 4     Ramicane     k403         20
# 25
# 25
# 24
# 24
# 23
# 23
# 23
# 21
# 20
# 20
# Text(0, 0.5, 'Number of mice')

# %% [markdown]
# ## Pie Plots

# %%
# Generate a pie plot showing the distribution of female versus male mice using pandas

# %%
# Generate a pie plot showing the distribution of female versus male mice using pyplot

# number of Gender types
Gender_count_df = merge_df["Sex"].value_counts()
Gender_count_df

# Pie chart, where the slices will be ordered and plotted counter-clockwise:
labels = 'female', 'male'
sizes = [935, 958]
explode = (0, 0.1)  # only "explode" the 2nd slice (i.e. 'male')

fig1, ax1 = plt.subplots()
ax1.pie(sizes, explode=explode, labels=labels, autopct='%1.1f%%',
        shadow=True, startangle=90)
ax1.axis('equal')  # Equal aspect ratio ensures that pie is drawn as a circle.

plt.show()

# %% [markdown]
# ## Quartiles, Outliers and Boxplots

# %%
# Calculate the final tumor volume of each mouse across four of the most promising treatment regimens. Calculate the IQR and quantitatively determine if there are any potential outliers.

# %%
# Generate a box plot of the final tumor volume of each mouse across four regimens of interest

# %% [markdown]
# ## Line and Scatter Plots

# %%
# Generate a line plot of time point versus tumor volume for a mouse treated with Capomulin

# %%
# Generate a scatter plot of mouse weight versus average tumor volume for the Capomulin regimen

# %% [markdown]
# ## Correlation and Regression

# %%
# Calculate the correlation coefficient and linear regression model 
# for mouse weight and average tumor volume for the Capomulin regimen
